# %%
IzYoJXPXvRPjjTuNJzKl69g48zPtWbwP
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 23
#      20 blackrock_cik = "0001364742"
#      22 # Download the latest 13F filing for BlackRock
# ---> 23 download_13f_filings(blackrock_cik)
#      25 # Function to parse downloaded 13F filings
#      26 def parse_13f_filings(cik):
#
# Cell In[5], line 16, in download_13f_filings(cik, limit)
#       9 def download_13f_filings(cik, limit=1):
#      10     """
#      11     Download the latest 13F-HR filings for a given institution.
#      12     Args:
#      13         cik (str): CIK number of the institution (e.g., BlackRock: 0001364742)
#      14         limit (int): Number of latest filings to download
#      15     """
# ---> 16     dl.get("13F-HR", cik, amount=limit)  # Use .get() instead of .filing()
#      17     print(f"Downloaded {limit} filings for CIK {cik}")
#
# ...

# %%
# List of Hedge Fund CIKs 

"BlackRock": "0001364742",
"Vanguard": "0000102909",
"State Street": "0000093751",
"Berkshire Hathaway": "0001067983",
"Bridgewater Associates": "0001350694",
"Citadel Advisors": "0001423053",
"Renaissance Technologies": "0001037389",
"Elliott Management": "0000902165",

# %%
import requests
import pandas as pd

# 🔑 Your FMP API Key (replace with your actual API key)
FMP_API_KEY = "IzYoJXPXvRPjjTuNJzKl69g48zPtWbwP"

# 🎯 Define Company Symbol (Example: BlackRock)
company_ticker = "AAPL"

# 🌐 FMP API Endpoints
balance_sheet_url = f"https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company_ticker}?apikey={FMP_API_KEY}"
income_statement_url = f"https://financialmodelingprep.com/api/v3/income-statement/{company_ticker}?apikey={FMP_API_KEY}"
cash_flow_url = f"https://financialmodelingprep.com/api/v3/cash-flow-statement/{company_ticker}?apikey={FMP_API_KEY}"
stock_price_url = f"https://financialmodelingprep.com/api/v3/quote/{company_ticker}?apikey={FMP_API_KEY}"
ratios_url = f"https://financialmodelingprep.com/api/v3/ratios/{company_ticker}?apikey={FMP_API_KEY}"

# Function to fetch data from API
def fetch_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

# 📈 Fetch Financial Data
balance_sheet = fetch_data(balance_sheet_url)
income_statement = fetch_data(income_statement_url)
cash_flow = fetch_data(cash_flow_url)
stock_price = fetch_data(stock_price_url)
ratios = fetch_data(ratios_url)

# 🏦 Convert Data to DataFrames
balance_sheet_df = pd.DataFrame(balance_sheet)
income_statement_df = pd.DataFrame(income_statement)
cash_flow_df = pd.DataFrame(cash_flow)
ratios_df = pd.DataFrame(ratios)

# %%
income_statement
# Out:
#           date symbol reportedCurrency         cik fillingDate  \
# 0   2024-09-28   AAPL              USD  0000320193  2024-11-01
# 1   2023-09-30   AAPL              USD  0000320193  2023-11-03
# 2   2022-09-24   AAPL              USD  0000320193  2022-10-28
# 3   2021-09-25   AAPL              USD  0000320193  2021-10-29
# 4   2020-09-26   AAPL              USD  0000320193  2020-10-30
# 5   2019-09-28   AAPL              USD  0000320193  2019-10-31
# 6   2018-09-29   AAPL              USD  0000320193  2018-11-05
# 7   2017-09-30   AAPL              USD  0000320193  2017-11-03
# 8   2016-09-24   AAPL              USD  0000320193  2016-10-26
# 9   2015-09-26   AAPL              USD  0000320193  2015-10-28
# 10  2014-09-27   AAPL              USD  0000320193  2014-10-27
# 11  2013-09-28   AAPL              USD  0000320193  2013-10-30
# 12  2012-09-29   AAPL              USD  0000320193  2012-10-31
# 13  2011-09-24   AAPL              USD  0000320193  2011-10-26
# ...
